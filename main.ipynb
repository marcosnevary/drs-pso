# %% [markdown]
# # Setup

# %%
import time
from collections.abc import Callable
from functools import partial
from pathlib import Path
from typing import NamedTuple

import jax
import jax.numpy as jnp
import jaxopt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from jax import block_until_ready, jit, lax, pmap, random, vmap

# %%
config = {
    "output_path": Path("./results/"),
}

# %% [markdown]
# # Algorithms

# %%
class SwarmState(NamedTuple):
    positions: np.ndarray
    velocities: np.ndarray
    p_best_pos: np.ndarray
    p_best_fit: np.ndarray
    g_best_pos: np.ndarray
    g_best_fit: np.ndarray
    rng: np.random.Generator
    history: np.ndarray

# %%
class JaxSwarmState(NamedTuple):
    positions: jnp.ndarray
    velocities: jnp.ndarray
    p_best_pos: jnp.ndarray
    p_best_fit: jnp.ndarray
    g_best_pos: jnp.ndarray
    g_best_fit: jnp.ndarray
    rng: random.PRNGKey

# %% [markdown]
# ## PSO (NumPy)

# %%
def pso(
    objective_fn: callable,
    bounds: tuple,
    num_dims: int,
    num_particles: int,
    max_iters: int,
    c1: float,
    c2: float,
    w: float,
    seed: int,
    **_: any,
) -> tuple:
    lower, upper = bounds
    rng = np.random.default_rng(seed)

    init_positions = rng.uniform(lower, upper, (num_particles, num_dims))
    init_velocities = np.zeros((num_particles, num_dims))
    init_fitness = np.array([objective_fn(position) for position in init_positions])

    best_idx = np.argmin(init_fitness)
    g_best_pos = init_positions[best_idx]
    g_best_fit = init_fitness[best_idx]

    history = np.zeros(max_iters)
    history[0] = g_best_fit

    swarm_state = SwarmState(
        positions=init_positions,
        velocities=init_velocities,
        p_best_pos=init_positions,
        p_best_fit=init_fitness,
        g_best_pos=g_best_pos,
        g_best_fit=g_best_fit,
        rng=rng,
        history=history,
    )

    for i in range(max_iters):
        r1 = swarm_state.rng.random((num_particles, num_dims))
        r2 = swarm_state.rng.random((num_particles, num_dims))

        inertia = w * swarm_state.velocities
        cognitive = c1 * r1 * (swarm_state.p_best_pos - swarm_state.positions)
        social = c2 * r2 * (swarm_state.g_best_pos - swarm_state.positions)

        new_velocities = inertia + cognitive + social
        new_positions = swarm_state.positions + new_velocities
        new_positions = np.clip(new_positions, lower, upper)

        new_fitness = np.array([objective_fn(pos) for pos in new_positions])

        improved = new_fitness < swarm_state.p_best_fit
        mask = improved[:, None]
        new_p_best_pos = np.where(mask, new_positions, swarm_state.p_best_pos)
        new_p_best_fit = np.where(improved, new_fitness, swarm_state.p_best_fit)

        current_g_best_idx = np.argmin(new_p_best_fit)
        current_g_best_fit = new_p_best_fit[current_g_best_idx]
        global_improved = current_g_best_fit < swarm_state.g_best_fit
        new_g_best_pos = np.where(
            global_improved,
            new_p_best_pos[current_g_best_idx],
            swarm_state.g_best_pos,
        )
        new_g_best_fit = np.where(
            global_improved,
            current_g_best_fit,
            swarm_state.g_best_fit,
        )

        new_history = swarm_state.history
        new_history[i] = new_g_best_fit

        swarm_state = SwarmState(
            positions=new_positions,
            velocities=new_velocities,
            p_best_pos=new_p_best_pos,
            p_best_fit=new_p_best_fit,
            g_best_pos=new_g_best_pos,
            g_best_fit=new_g_best_fit,
            rng=swarm_state.rng,
            history=new_history,
        )

    return swarm_state.g_best_pos, swarm_state.g_best_fit, swarm_state.history

# %% [markdown]
# ## PSO (JAX)

# %%
@partial(
    jit,
    static_argnames=(
        "objective_fn",
        "num_dims",
        "num_particles",
        "max_iters",
    ),
)
def pso_jax(
    objective_fn: Callable,
    bounds: tuple,
    num_dims: int,
    num_particles: int,
    max_iters: int,
    c1: float,
    c2: float,
    w: float,
    seed: random.PRNGKey,
    **_: any,
) -> tuple:
    key = seed
    lower, upper = jnp.array(bounds[0]), jnp.array(bounds[1])
    k_pos, k_vel, k_state = random.split(key, 3)

    search_range = upper - lower
    velocity_scale = 0.1
    limit = search_range * velocity_scale

    init_positions = random.uniform(k_pos, (num_particles, num_dims), minval=lower, maxval=upper)
    init_velocities = random.uniform(k_vel, (num_particles, num_dims), minval=-limit, maxval=limit)
    init_fitness = vmap(objective_fn)(init_positions)

    best_idx = jnp.argmin(init_fitness)
    g_best_pos = init_positions[best_idx]
    g_best_fit = init_fitness[best_idx]

    initial_state = JaxSwarmState(
        positions=init_positions,
        velocities=init_velocities,
        p_best_pos=init_positions,
        p_best_fit=init_fitness,
        g_best_pos=g_best_pos,
        g_best_fit=g_best_fit,
        rng=k_state,
    )

    def update_step(swarm_state: JaxSwarmState, _: any) -> tuple:
        k1, k2, k_next = random.split(swarm_state.rng, 3)
        r1 = random.uniform(k1, (num_particles, num_dims))
        r2 = random.uniform(k2, (num_particles, num_dims))

        inertia = w * swarm_state.velocities
        cognitive = c1 * r1 * (swarm_state.p_best_pos - swarm_state.positions)
        social = c2 * r2 * (swarm_state.g_best_pos - swarm_state.positions)

        new_velocities = inertia + cognitive + social
        new_positions = swarm_state.positions + new_velocities
        new_positions = jnp.clip(new_positions, lower, upper)

        new_fitness = vmap(objective_fn)(new_positions)

        improved = new_fitness < swarm_state.p_best_fit

        new_p_best_pos = jnp.where(improved[:, None], new_positions, swarm_state.p_best_pos)
        new_p_best_fit = jnp.where(improved, new_fitness, swarm_state.p_best_fit)

        current_g_best_idx = jnp.argmin(new_p_best_fit)
        new_g_best_pos = new_p_best_pos[current_g_best_idx]
        new_g_best_fit = new_p_best_fit[current_g_best_idx]

        global_improved = new_g_best_fit < swarm_state.g_best_fit

        final_g_best_pos = jnp.where(global_improved, new_g_best_pos, swarm_state.g_best_pos)
        final_g_best_fit = jnp.where(global_improved, new_g_best_fit, swarm_state.g_best_fit)

        next_state = JaxSwarmState(
            positions=new_positions,
            velocities=new_velocities,
            p_best_pos=new_p_best_pos,
            p_best_fit=new_p_best_fit,
            g_best_pos=final_g_best_pos,
            g_best_fit=final_g_best_fit,
            rng=k_next,
        )

        return next_state, final_g_best_fit

    final_state, history = lax.scan(update_step, initial_state, jnp.arange(max_iters))
    full_history = jnp.concatenate([jnp.array([initial_state.g_best_fit]), history])

    return final_state.g_best_pos, final_state.g_best_fit, full_history

# %% [markdown]
# ## PSOX (NumPy + SciPy)

# %%
def numerical_gradient(objective_fn: callable, x: np.ndarray, epsilon: float = 1e-8) -> np.ndarray:
    grad = np.zeros_like(x)
    for i in range(len(x)):
        x_plus = x.copy()
        x_plus[i] += epsilon
        x_minus = x.copy()
        x_minus[i] -= epsilon
        grad[i] = (objective_fn(x_plus) - objective_fn(x_minus)) / (2 * epsilon)
    return grad


def gradient_descent(
    objective_fn: callable,
    initial_pos: np.ndarray,
    bounds: tuple,
    eta: float,
    steps: int,
) -> tuple:
    lower, upper = bounds
    current_pos = initial_pos.copy()

    for _ in range(steps):
        grad = numerical_gradient(objective_fn, current_pos)
        current_pos = current_pos - eta * grad
        current_pos = np.clip(current_pos, lower, upper)

    final_fit = objective_fn(current_pos)
    return current_pos, final_fit


def gdpso(
    objective_fn: callable,
    bounds: tuple,
    num_dims: int,
    num_particles: int,
    max_iters: int,
    c1: float,
    c2: float,
    w: float,
    seed: int,
    eta: float,
    steps: int,
    gd_interval: int,
    **_: any,
) -> tuple:
    lower, upper = bounds
    rng = np.random.default_rng(seed)

    init_positions = rng.uniform(lower, upper, (num_particles, num_dims))
    init_velocities = np.zeros((num_particles, num_dims))
    init_fitness = np.array([objective_fn(position) for position in init_positions])

    best_idx = np.argmin(init_fitness)
    g_best_pos = init_positions[best_idx]
    g_best_fit = init_fitness[best_idx]

    history = np.zeros(max_iters)
    history[0] = g_best_fit

    swarm_state = SwarmState(
        positions=init_positions,
        velocities=init_velocities,
        p_best_pos=init_positions,
        p_best_fit=init_fitness,
        g_best_pos=g_best_pos,
        g_best_fit=g_best_fit,
        rng=rng,
        history=history,
    )

    for i in range(max_iters):
        r1 = swarm_state.rng.random((num_particles, num_dims))
        r2 = swarm_state.rng.random((num_particles, num_dims))

        inertia = w * swarm_state.velocities
        cognitive = c1 * r1 * (swarm_state.p_best_pos - swarm_state.positions)
        social = c2 * r2 * (swarm_state.g_best_pos - swarm_state.positions)

        new_velocities = inertia + cognitive + social
        new_positions = swarm_state.positions + new_velocities
        new_positions = np.clip(new_positions, lower, upper)

        new_fitness = np.array([objective_fn(pos) for pos in new_positions])

        improved = new_fitness < swarm_state.p_best_fit
        mask = improved[:, None]
        new_p_best_pos = np.where(mask, new_positions, swarm_state.p_best_pos)
        new_p_best_fit = np.where(improved, new_fitness, swarm_state.p_best_fit)

        current_g_best_idx = np.argmin(new_p_best_fit)
        current_g_best_fit = new_p_best_fit[current_g_best_idx]
        global_improved = current_g_best_fit < swarm_state.g_best_fit

        candidate_g_pos = np.where(
            global_improved,
            new_p_best_pos[current_g_best_idx],
            swarm_state.g_best_pos,
        )
        candidate_g_fit = np.where(
            global_improved,
            current_g_best_fit,
            swarm_state.g_best_fit,
        )

        if i % gd_interval == 0:
            gradient_g_pos, gradient_g_fit = gradient_descent(
                objective_fn,
                candidate_g_pos,
                bounds,
                eta,
                steps,
            )

            gd_improved = gradient_g_fit < candidate_g_fit
            final_g_pos = gradient_g_pos if gd_improved else candidate_g_pos
            final_g_fit = gradient_g_fit if gd_improved else candidate_g_fit

            if gd_improved and (final_g_fit < swarm_state.g_best_fit):
                new_p_best_pos[current_g_best_idx] = final_g_pos
                new_p_best_fit[current_g_best_idx] = final_g_fit
        else:
            final_g_pos = candidate_g_pos
            final_g_fit = candidate_g_fit

        new_history = swarm_state.history
        new_history[i] = final_g_fit

        swarm_state = SwarmState(
            positions=new_positions,
            velocities=new_velocities,
            p_best_pos=new_p_best_pos,
            p_best_fit=new_p_best_fit,
            g_best_pos=final_g_pos,
            g_best_fit=final_g_fit,
            rng=swarm_state.rng,
            history=new_history,
        )

    return swarm_state.g_best_pos, swarm_state.g_best_fit, swarm_state.history

# %% [markdown]
# ## PSOX (JAX + JAXopt)

# %%
class GradientState(NamedTuple):
    current_pos: jnp.ndarray


@partial(
    jit,
    static_argnames=(
        "objective_fn",
        "num_dims",
        "num_particles",
        "max_iters",
        "steps",
        "gd_interval",
        "eta",
    ),
)
def gdpso_jax(
    objective_fn: Callable,
    bounds: tuple,
    num_dims: int,
    num_particles: int,
    max_iters: int,
    c1: float,
    c2: float,
    w: float,
    seed: random.PRNGKey,
    eta: float,
    steps: int,
    gd_interval: int,
    **_: any,
) -> tuple:
    key = seed
    lower, upper = jnp.array(bounds[0]), jnp.array(bounds[1])
    k_pos, k_vel, k_state = random.split(key, 3)

    search_range = upper - lower
    velocity_scale = 0.1
    limit = search_range * velocity_scale

    init_positions = random.uniform(k_pos, (num_particles, num_dims), minval=lower, maxval=upper)
    init_velocities = random.uniform(k_vel, (num_particles, num_dims), minval=-limit, maxval=limit)
    init_fitness = vmap(objective_fn)(init_positions)

    best_idx = jnp.argmin(init_fitness)
    g_best_pos = init_positions[best_idx]
    g_best_fit = init_fitness[best_idx]

    initial_state = JaxSwarmState(
        positions=init_positions,
        velocities=init_velocities,
        p_best_pos=init_positions,
        p_best_fit=init_fitness,
        g_best_pos=g_best_pos,
        g_best_fit=g_best_fit,
        rng=k_state,
    )

    gd_solver = jaxopt.GradientDescent(
        fun=objective_fn,
        stepsize=eta,
        implicit_diff=False,
    )

    def update_step(swarm_state: JaxSwarmState, i: int) -> tuple:
        k1, k2, k_next = random.split(swarm_state.rng, 3)
        r1 = random.uniform(k1, (num_particles, num_dims))
        r2 = random.uniform(k2, (num_particles, num_dims))

        inertia = w * swarm_state.velocities
        cognitive = c1 * r1 * (swarm_state.p_best_pos - swarm_state.positions)
        social = c2 * r2 * (swarm_state.g_best_pos - swarm_state.positions)

        new_velocities = inertia + cognitive + social
        new_positions = swarm_state.positions + new_velocities
        new_positions = jnp.clip(new_positions, lower, upper)

        new_fitness = vmap(objective_fn)(new_positions)

        improved = new_fitness < swarm_state.p_best_fit

        new_p_best_pos = jnp.where(improved[:, None], new_positions, swarm_state.p_best_pos)
        new_p_best_fit = jnp.where(improved, new_fitness, swarm_state.p_best_fit)

        current_g_best_idx = jnp.argmin(new_p_best_fit)
        current_g_best_fit = new_p_best_fit[current_g_best_idx]

        global_improved = current_g_best_fit < swarm_state.g_best_fit

        candidate_g_pos = jnp.where(
            global_improved,
            new_p_best_pos[current_g_best_idx],
            swarm_state.g_best_pos,
        )

        candidate_g_fit = jnp.where(global_improved, current_g_best_fit, swarm_state.g_best_fit)

        def apply_gd(_: None) -> tuple:
            init_gd_state = gd_solver.init_state(candidate_g_pos)

            def gd_step(carry: tuple, _: None) -> tuple:
                pos, state = carry

                next_pos, next_state = gd_solver.update(pos, state)
                next_pos = jnp.clip(next_pos, lower, upper)

                return (next_pos, next_state), None

            (final_pos, _), _ = lax.scan(
                gd_step,
                (candidate_g_pos, init_gd_state),
                None,
                steps,
            )

            final_fit = objective_fn(final_pos)
            return final_pos, final_fit

        def skip_gd(_: None) -> tuple:
            return candidate_g_pos, candidate_g_fit

        gradient_g_pos, gradient_g_fit = lax.cond(
            i % gd_interval == 0,
            apply_gd,
            skip_gd,
            None,
        )

        gd_improved = gradient_g_fit < candidate_g_fit
        final_g_pos = jnp.where(gd_improved, gradient_g_pos, candidate_g_pos)
        final_g_fit = jnp.where(gd_improved, gradient_g_fit, candidate_g_fit)

        any_improvement = final_g_fit < swarm_state.g_best_fit

        target_idx = current_g_best_idx

        mask_winner = (jnp.arange(num_particles) == target_idx)[:, None]
        should_update_mask = (gd_improved & any_improvement) & mask_winner

        final_p_best_pos = jnp.where(
            should_update_mask,
            final_g_pos,
            new_p_best_pos,
        )

        final_p_best_fit = jnp.where(
            (gd_improved & any_improvement) & (jnp.arange(num_particles) == target_idx),
            final_g_fit,
            new_p_best_fit,
        )

        next_state = JaxSwarmState(
            positions=new_positions,
            velocities=new_velocities,
            p_best_pos=final_p_best_pos,
            p_best_fit=final_p_best_fit,
            g_best_pos=final_g_pos,
            g_best_fit=final_g_fit,
            rng=k_next,
        )

        return next_state, final_g_fit

    final_state, history = lax.scan(update_step, initial_state, jnp.arange(max_iters))
    full_history = jnp.concatenate([jnp.array([initial_state.g_best_fit]), history])

    return final_state.g_best_pos, final_state.g_best_fit, full_history

# %% [markdown]
# # Visualizations

# %%
def _save_figure(fig: plt.Figure, filename: str, config: dict) -> None:
    save_path = config["output_path"] / filename
    fig.savefig(save_path, bbox_inches="tight", format="pdf", dpi=300)
    plt.close(fig)


def plot_execution_time(df: pd.DataFrame, config: dict) -> None:
    benchmarks = df["Benchmark"].unique()
    algorithms = df["Algorithm"].unique()
    dimensions = df["Dimension"].unique()

    colors = ["#909090", "#0056AD", "#6D87A1", "#0080FF"]

    plt.rcParams.update(
        {
            "font.size": 11,
            "axes.titlesize": 11,
            "axes.labelsize": 11,
            "xtick.labelsize": 11,
            "ytick.labelsize": 11,
            "legend.fontsize": 11,
        },
    )

    fig, axes = plt.subplots(2, 2, figsize=(5, 4), sharex=True, sharey=True)
    axes_flattened = axes.flatten()

    lines = []
    labels = []

    for idx_ax, (ax, benchmark) in enumerate(zip(axes_flattened, benchmarks)):
        df_benchmark = df[df["Benchmark"] == benchmark]

        for idx_algo, algorithm in enumerate(algorithms):
            df_subset = df_benchmark[df_benchmark["Algorithm"] == algorithm]
            mean = df_subset["Mean of Execution Times (s)"]
            std = df_subset["Standard Deviation of Execution Times (s)"]

            (line,) = ax.plot(
                dimensions,
                mean,
                label=algorithm,
                marker="o",
                color=colors[idx_algo],
                markersize=6,
                linewidth=2,
            )
            ax.fill_between(dimensions, mean - std, mean + std, color=colors[idx_algo], alpha=0.2)

            if idx_ax == 0:
                lines.append(line)
                labels.append(algorithm)

        ax.set_yscale("log")
        ax.set_title(f"{benchmark}")
        sns.despine(ax=ax, left=True)

    fig.supxlabel("Dimensão")
    fig.supylabel("Tempo de Execução (s)")

    fig.legend(
        lines,
        labels,
        loc="upper center",
        bbox_to_anchor=(0.5, 1.05),
        ncol=len(algorithms),
        frameon=False,
    )

    plt.tight_layout()
    _save_figure(fig, "execution_time_plot.pdf", config)


def plot_convergence(df: pd.DataFrame, config: dict) -> None:
    plt.rcParams.update(
        {
            "font.size": 13,
            "axes.titlesize": 13,
            "axes.labelsize": 13,
            "xtick.labelsize": 13,
            "ytick.labelsize": 13,
            "legend.fontsize": 13,
        },
    )

    benchmarks = df["Benchmark"].unique()
    dimensions = df["Dimension"].unique()
    algorithms = df["Algorithm"].unique()

    colors = ["#909090", "#0056AD", "#6D87A1", "#0080FF"]

    fig, axes = plt.subplots(4, 4, figsize=(12, 12), sharex=True)

    lines = []
    labels = []

    for i, benchmark in enumerate(benchmarks):
        for j, dimension in enumerate(dimensions):
            ax = axes[i, j]
            df_subset = df[(df["Dimension"] == dimension) & (df["Benchmark"] == benchmark)]

            for k, (_, row) in enumerate(df_subset.iterrows()):
                mean_history = jnp.array(row["Mean Fitness History"])
                std_history = jnp.array(row["Std Fitness History"])
                iterations = range(len(mean_history))

                (line,) = ax.plot(
                    iterations,
                    mean_history,
                    label=row["Algorithm"],
                    color=colors[k],
                    linewidth=2,
                )
                ax.fill_between(
                    iterations,
                    mean_history - std_history,
                    mean_history + std_history,
                    alpha=0.2,
                    color=colors[k],
                )

                if i == 0 and j == 0:
                    lines.append(line)
                    labels.append(row["Algorithm"])

            sns.despine(ax=ax, left=True)
            ax.set_title(f"{benchmark} (d = {dimension})")

    fig.supxlabel("Iteração")
    fig.supylabel("Fitness")

    fig.legend(
        lines,
        labels,
        loc="upper center",
        bbox_to_anchor=(0.5, 1.03),
        ncol=len(algorithms),
        frameon=False,
    )

    plt.tight_layout()
    _save_figure(fig, "convergence_plot.pdf", config)


def _generate_comparison_table(
    df: pd.DataFrame,
    config: dict,
    mean_col: str,
    std_col: str,
    output_filename: str,
    caption: str,
    label: str,
) -> None:
    df_proc = df.copy()

    df_proc["formatted"] = (
        df_proc[mean_col].map("{:.2e}".format) + r" $\pm$ " + df_proc[std_col].map("{:.2e}".format)
    )

    df_pivot = df_proc.pivot_table(
        index=["Benchmark", "Dimension"],
        columns="Algorithm",
        values=["formatted", mean_col],
        aggfunc="first",
    )

    means = df_pivot[mean_col].fillna(float("inf"))

    display_df = df_pivot["formatted"].copy()

    for idx in display_df.index:
        row_means = means.loc[idx]
        best_algo = row_means.idxmin()
        if pd.notna(display_df.loc[idx, best_algo]):
            display_df.loc[idx, best_algo] = r"\textbf{" + display_df.loc[idx, best_algo] + "}"

    display_df = display_df.reset_index()

    display_df["Benchmark"] = display_df["Benchmark"].apply(lambda x: f"\\textit{{{x}}}")

    for col in display_df.columns:
        if col not in ["Benchmark", "Dimension"]:
            display_df = display_df.rename(columns={col: f"\\textit{{{col}}}"})

    output_path = config["output_path"] / output_filename

    num_algo_cols = len(display_df.columns) - 2
    column_format = "ll" + "c" * num_algo_cols

    latex_code = display_df.style.hide(axis="index").to_latex(
        column_format=column_format,
        hrules=True,
        caption=caption,
        label=label,
        position="h",
    )

    with output_path.open("w") as f:
        f.write(latex_code)


def create_convergence_table(df: pd.DataFrame, config: dict) -> None:
    _generate_comparison_table(
        df=df,
        config=config,
        mean_col="Mean of Fitness",
        std_col="Standard Deviation of Fitness",
        output_filename="convergence_table.tex",
        caption=r"Convergence comparison (Mean Fitness $\pm$ Std Dev). Best results in bold.",
        label="tab:convergence",
    )


def create_execution_time_table(df: pd.DataFrame, config: dict) -> None:
    _generate_comparison_table(
        df=df,
        config=config,
        mean_col="Mean of Execution Times (s)",
        std_col="Standard Deviation of Execution Times (s)",
        output_filename="execution_time_table.tex",
        caption="Execution time comparison in seconds.",
        label="tab:execution_time",
    )


def generate_visualizations(df: pd.DataFrame, config: dict) -> None:
    print("Plotting convergence...")
    plot_convergence(df, config)

    print("Plotting execution time...")
    plot_execution_time(df, config)

    print("Creating convergence table (LaTeX)...")
    create_convergence_table(df, config)

    print("Creating execution time table (LaTeX)...")
    create_execution_time_table(df, config)

# %% [markdown]
# # Benchmark Functions

# %% [markdown]
# ## NumPy

# %%
def schwefel_np(x: np.ndarray) -> float:
    n = x.shape[0]
    sum_term = np.sum(x * np.sin(np.sqrt(np.abs(x))))
    return 418.9829 * n - sum_term


def rastrigin_np(x: np.ndarray) -> float:
    n = x.shape[0]
    return 10 * n + np.sum(x**2 - 10 * np.cos(2 * np.pi * x))


def sphere_np(x: np.ndarray) -> float:
    return np.sum(x**2)


def elliptic_np(x: np.ndarray) -> float:
    n = x.shape[0]
    i = np.arange(n)
    coeffs = (1e6) ** (i / (n - 1))
    return np.sum(coeffs * x**2)

# %% [markdown]
# ## JAX

# %%
@jit
def schwefel_jax(x: jnp.ndarray) -> jnp.ndarray:
    n = x.shape[0]
    sum_term = jnp.sum(x * jnp.sin(jnp.sqrt(jnp.abs(x))))
    return 418.9829 * n - sum_term


@jit
def rastrigin_jax(x: jnp.ndarray) -> jnp.ndarray:
    n = x.shape[0]
    return 10 * n + jnp.sum(x**2 - 10 * jnp.cos(2 * jnp.pi * x))


@jit
def sphere_jax(x: jnp.ndarray) -> jnp.ndarray:
    return jnp.sum(x**2)


@jit
def elliptic_jax(x: jnp.ndarray) -> jnp.ndarray:
    n = x.shape[0]
    i = jnp.arange(n)

    coeffs = (1e6) ** (i / (n - 1))
    return jnp.sum(coeffs * x**2)

# %% [markdown]
# # Configurataion

# %%
BENCHMARKS = {
    "Schwefel": {
        "bounds": (-500, 500),
        "NumPy": schwefel_np,
        "JAX": schwefel_jax,
    },
    "Rastrigin": {
        "bounds": (-5.12, 5.12),
        "NumPy": rastrigin_np,
        "JAX": rastrigin_jax,
    },
    "Elliptic": {
        "bounds": (-5.0, 10.0),
        "NumPy": elliptic_np,
        "JAX": elliptic_jax,
    },
    "Sphere": {
        "bounds": (-5.12, 5.12),
        "NumPy": sphere_np,
        "JAX": sphere_jax,
    },
}

ALGORITHMS = {
    "PSO": pso,
    "GDPSO": gdpso,
    "PSO-JAX": pso_jax,
    "GDPSO-JAX": gdpso_jax,
}

DIMS = [2, 10, 30, 50]

HYPERPARAMETERS = {
    "num_dims": None,
    "num_particles": 30,
    "max_iters": 1000,
    "c1": 1.5,
    "c2": 2.5,
    "w": 0.7,
    "seed": None,
    "eta": 0.001,
    "steps": 10,
    "gd_interval": 10,
}

NUM_RUNS = 5

# %%
num_devices = jax.device_count()

params = {
    "objective_fn": schwefel_jax,
    "bounds": (-500, 500),
    "num_dims": 10,
    "num_particles": 30,
    "max_iters": 200,
    "c1": 1.5,
    "c2": 2.5,
    "w": 0.7,
    "eta": 0.001,
    "steps": 10,
    "gd_interval": 10,
}

def run_pso_jax(seed: random.PRNGKey) -> tuple:
    best_pos, best_fit, history = gdpso_jax(**params, seed=seed)
    return best_pos, best_fit, history

x = [params for _ in range(8)]

print(len(x))

parallel_pso = pmap(run_pso_jax)

base_key = jax.random.PRNGKey(42)
seeds = jax.random.split(base_key, num_devices)

all_best_pos, all_best_fits, all_histories = parallel_pso(seeds)
print(all_best_fits)
# Out:
# 8
# [1191.9697   715.1948   358.0913   599.24243  715.21826  715.13525
#   476.86523 1071.0022 ]

# %% [markdown]
# # Experiments

# %%
def run_experiment() -> list[dict]:
    results = []

    total_configs = len(DIMS) * len(ALGORITHMS) * len(BENCHMARKS)
    current_config = 0

    for dim in DIMS:
        print(f"Dimension: {dim}")
        for algorithm_name, algorithm_fn in ALGORITHMS.items():
            backend = "JAX" if "JAX" in algorithm_name else "NumPy"

            for benchmark_name, benchmark_config in BENCHMARKS.items():
                current_config += 1

                objective_fn = benchmark_config[backend]
                bounds = benchmark_config["bounds"]
                hyperparameters = HYPERPARAMETERS.copy()
                hyperparameters["num_dims"] = dim

                print(
                    f"[{current_config}/{total_configs}] Running {algorithm_name} "
                    f"on {benchmark_name}",
                )

                execution_times = []
                fitness_history = []
                for i in range(NUM_RUNS):
                    hyperparameters["seed"] = i

                    if "JAX" in algorithm_name:
                        hyperparameters["seed"] = random.PRNGKey(i)
                        algorithm_fn(objective_fn, bounds, **hyperparameters)

                    start = time.perf_counter()
                    result = algorithm_fn(objective_fn, bounds, **hyperparameters)

                    if "JAX" in algorithm_name:
                        block_until_ready(result)

                    end = time.perf_counter()
                    execution_times.append(end - start)

                    _, fitness, history = result

                    print(f"Iteration {i + 1} | Fitness: {fitness}")
                    fitness_history.append(history)

                mean_fitness_history = jnp.mean(jnp.array(fitness_history), axis=0)
                std_fitness_history = jnp.std(jnp.array(fitness_history), axis=0)

                mean_time = float(jnp.mean(jnp.array(execution_times)))
                std_time = float(jnp.std(jnp.array(execution_times)))

                mean_fitness = float(jnp.mean(mean_fitness_history))
                std_fitness = float(jnp.std(std_fitness_history))

                results.extend(
                    [
                        {
                            "Dimension": dim,
                            "Benchmark": benchmark_name,
                            "Algorithm": algorithm_name,
                            "Execution Time History": execution_times,
                            "Mean of Execution Times (s)": mean_time,
                            "Standard Deviation of Execution Times (s)": std_time,
                            "Mean Fitness History": mean_fitness_history.tolist(),
                            "Std Fitness History": std_fitness_history.tolist(),
                            "Mean of Fitness": mean_fitness,
                            "Standard Deviation of Fitness": std_fitness,
                        },
                    ],
                )

    return results

# %%
results = run_experiment()
df = pd.DataFrame(results)
# Out:
# Dimension: 2
# [1/64] Running PSO on Schwefel
# Iteration 1 | Fitness: 2.5455132345086895e-05
# Iteration 2 | Fitness: 2.5455132345086895e-05
# Iteration 3 | Fitness: 118.43836006957031
# Iteration 4 | Fitness: 2.5455132345086895e-05
# Iteration 5 | Fitness: 2.5455132345086895e-05
# [2/64] Running PSO on Rastrigin
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [3/64] Running PSO on Elliptic
# Iteration 1 | Fitness: 7.072503070444464e-44
# Iteration 2 | Fitness: 2.4826160717399577e-44
# Iteration 3 | Fitness: 3.427936377759538e-49
# Iteration 4 | Fitness: 3.8542517232605337e-47
# Iteration 5 | Fitness: 7.572174693455623e-46
# [4/64] Running PSO on Sphere
# Iteration 1 | Fitness: 4.646779119397927e-53
# Iteration 2 | Fitness: 6.312318806743982e-51
# Iteration 3 | Fitness: 3.914938068778477e-52
# Iteration 4 | Fitness: 1.4254706276655222e-44
# Iteration 5 | Fitness: 7.836512805285942e-47
# [5/64] Running GDPSO on Schwefel
# Iteration 1 | Fitness: 2.5455132345086895e-05
# Iteration 2 | Fitness: 2.5455132345086895e-05
# Iteration 3 | Fitness: 118.43836006957031
# Iteration 4 | Fitness: 2.5455132345086895e-05
# Iteration 5 | Fitness: 2.5455132345086895e-05
# [6/64] Running GDPSO on Rastrigin
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [7/64] Running GDPSO on Elliptic
# Iteration 1 | Fitness: 6.596016999067246e-44
# Iteration 2 | Fitness: 2.432341001771226e-44
# Iteration 3 | Fitness: 1.2611779549623485e-48
# Iteration 4 | Fitness: 5.587712093909558e-44
# Iteration 5 | Fitness: 1.5550420235152433e-46
# [8/64] Running GDPSO on Sphere
# Iteration 1 | Fitness: 8.113739439359705e-49
# Iteration 2 | Fitness: 1.3071439212245909e-51
# Iteration 3 | Fitness: 1.9391032267095454e-52
# Iteration 4 | Fitness: 1.539289843716009e-48
# Iteration 5 | Fitness: 3.8014256402510196e-51
# [9/64] Running PSO-JAX on Schwefel
# Iteration 1 | Fitness: 118.43829345703125
# Iteration 2 | Fitness: -6.103515625e-05
# Iteration 3 | Fitness: -6.103515625e-05
# Iteration 4 | Fitness: -6.103515625e-05
# Iteration 5 | Fitness: 238.393798828125
# [10/64] Running PSO-JAX on Rastrigin
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [11/64] Running PSO-JAX on Elliptic
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [12/64] Running PSO-JAX on Sphere
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [13/64] Running GDPSO-JAX on Schwefel
# Iteration 1 | Fitness: 118.43829345703125
# Iteration 2 | Fitness: -6.103515625e-05
# Iteration 3 | Fitness: -6.103515625e-05
# Iteration 4 | Fitness: -6.103515625e-05
# Iteration 5 | Fitness: 238.393798828125
# [14/64] Running GDPSO-JAX on Rastrigin
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [15/64] Running GDPSO-JAX on Elliptic
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# [16/64] Running GDPSO-JAX on Sphere
# Iteration 1 | Fitness: 0.0
# Iteration 2 | Fitness: 0.0
# Iteration 3 | Fitness: 0.0
# Iteration 4 | Fitness: 0.0
# Iteration 5 | Fitness: 0.0
# Dimension: 10
# [17/64] Running PSO on Schwefel
# Iteration 1 | Fitness: 476.7875847579262
# Iteration 2 | Fitness: 833.619648113227
# Iteration 3 | Fitness: 833.6196481132279
# Iteration 4 | Fitness: 1070.4963173421029
# Iteration 5 | Fitness: 1190.451711468706
# [18/64] Running PSO on Rastrigin
# Iteration 1 | Fitness: 2.9855509418214154
# Iteration 2 | Fitness: 36.88536718284146
# Iteration 3 | Fitness: 4.9835721896049705
# Iteration 4 | Fitness: 32.02878384300176
# Iteration 5 | Fitness: 2.8574044679385793
# [19/64] Running PSO on Elliptic
# Iteration 1 | Fitness: 56231.341661669314
# Iteration 2 | Fitness: 216.039720843464
# Iteration 3 | Fitness: 51170.323026159655
# Iteration 4 | Fitness: 22093.13096739322
# Iteration 5 | Fitness: 306924.47592330497
# [20/64] Running PSO on Sphere
# Iteration 1 | Fitness: 2.5801385830552714e-09
# Iteration 2 | Fitness: 1.5971014413724344e-07
# Iteration 3 | Fitness: 4.3466454955016494e-10
# Iteration 4 | Fitness: 1.01851428468881e-07
# Iteration 5 | Fitness: 1.6644690290000943e-09
# [21/64] Running GDPSO on Schwefel
# Iteration 1 | Fitness: 476.7875847577561
# Iteration 2 | Fitness: 833.619648113226
# Iteration 3 | Fitness: 833.6196481132274
# Iteration 4 | Fitness: 1070.4963173421042
# Iteration 5 | Fitness: 1190.451711468706
# [22/64] Running GDPSO on Rastrigin
# Iteration 1 | Fitness: 26.362268609316843
# Iteration 2 | Fitness: 24.87372293454223
# Iteration 3 | Fitness: 26.86364104872885
# Iteration 4 | Fitness: 3.979836228373159
# Iteration 5 | Fitness: 3.9798362283731734
# [23/64] Running GDPSO on Elliptic
# Iteration 1 | Fitness: 56231.341661669314
# Iteration 2 | Fitness: 216.039720843464
# Iteration 3 | Fitness: 51170.323026159655
# Iteration 4 | Fitness: 22093.13096739322
# Iteration 5 | Fitness: 306924.47592330497
# [24/64] Running GDPSO on Sphere
# Iteration 1 | Fitness: 1.584738442621448e-13
# Iteration 2 | Fitness: 2.473111677344435e-10
# Iteration 3 | Fitness: 8.238972065739421e-11
# Iteration 4 | Fitness: 6.700337150217049e-12
# Iteration 5 | Fitness: 1.1333229424591643e-10
# [25/64] Running PSO-JAX on Schwefel
# Iteration 1 | Fitness: 595.22607421875
# Iteration 2 | Fitness: 952.05810546875
# Iteration 3 | Fitness: 833.61962890625
# Iteration 4 | Fitness: 1191.968994140625
# Iteration 5 | Fitness: 713.664306640625
# [26/64] Running PSO-JAX on Rastrigin
# Iteration 1 | Fitness: 6.28424072265625
# Iteration 2 | Fitness: 7.4219818115234375
# Iteration 3 | Fitness: 3.0097579956054688
# Iteration 4 | Fitness: 30.99329376220703
# Iteration 5 | Fitness: 2.7153854370117188
# [27/64] Running PSO-JAX on Elliptic
# Iteration 1 | Fitness: 10563.6103515625
# Iteration 2 | Fitness: 1102.767578125
# Iteration 3 | Fitness: 754.6484375
# Iteration 4 | Fitness: 22706.7421875
# Iteration 5 | Fitness: 563.6087036132812
# [28/64] Running PSO-JAX on Sphere
# Iteration 1 | Fitness: 8.597800693621593e-09
# Iteration 2 | Fitness: 1.1479934780567191e-09
# Iteration 3 | Fitness: 1.9714427312855776e-10
# Iteration 4 | Fitness: 2.941583643334411e-09
# Iteration 5 | Fitness: 6.6240657403682235e-09
# [29/64] Running GDPSO-JAX on Schwefel
# Iteration 1 | Fitness: 595.225830078125
# Iteration 2 | Fitness: 952.05810546875
# Iteration 3 | Fitness: 953.5751953125
# Iteration 4 | Fitness: 1191.968994140625
# Iteration 5 | Fitness: 713.664306640625
# [30/64] Running GDPSO-JAX on Rastrigin
# Iteration 1 | Fitness: 6.9647064208984375
# Iteration 2 | Fitness: 1.9899139404296875
# Iteration 3 | Fitness: 9.949569702148438
# Iteration 4 | Fitness: 5.969749450683594
# Iteration 5 | Fitness: 3.979827880859375
# [31/64] Running GDPSO-JAX on Elliptic
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2495, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, num_const_args, effects, in_avals, arg_names, result_names)
#    2494 try:
# -> 2495   func_op, _, _ = ctx.cached_primitive_lowerings[key]
#    2496 except KeyError:
#
# KeyError: ('closed_call', let _uniform = { lambda ; a:key<fry>[] b:f32[] c:f32[]. let
#     d:f32[] = convert_element_type[new_dtype=float32 weak_type=False] b
#     e:f32[] = convert_element_type[new_dtype=float32 weak_type=False] c
#     f:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 1)
#       sharding=None
#     ] d
#     g:f32[1,1] = broadcast_in_dim[
#       broadcast_dimensions=()
#       shape=(1, 1)
#       sharding=None
#     ] e
#     h:u32[30,10] = random_bits[bit_width=32 shape=(30, 10)] a
#     i:u32[30,10] = shift_right_logical h 9:u32[]
#     j:u32[30,10] = or i 1065353216:u32[]
#     k:f32[30,10] = bitcast_convert_type[new_dtype=float32] j
#     l:f32[30,10] = sub k 1.0:f32[]
#     m:f32[1,1] = sub g f
#     n:f32[30,10] = mul l m
#     o:f32[30,10] = add n f
#     p:f32[30,10] = max f o
#   in (p,) } in
# let _where = { lambda ; q:bool[] r:f32[10] s:f32[10]. let
#     t:f32[10] = select_n q s r
#   in (t,) } in
# let _where1 = { lambda ; u:bool[] v:f32[] w:f32[]. let
#     x:f32[] = select_n u w v
#   in (x,) } in
# { lambda ; y:f32[] z:f32[] ba:f32[] bb:f32[] bc:f32[] bd:f32[30,10] be:f32[30,10]
#     bf:f32[30,10] bg:f32[30] bh:f32[10] bi:f32[] bj:u32[2] bk:i32[]. let
#     bl:key<fry>[] = random_wrap[impl=fry] bj
#     bm:key<fry>[3] = random_split[shape=(3,)] bl
#     bn:u32[3,2] = random_unwrap bm
#     bo:u32[1,2] = slice[
#       limit_indices=(1, 2)
#       start_indices=(0, 0)
#       strides=(1, 1)
#     ] bn
#     bp:u32[2] = squeeze[dimensions=(0,)] bo
#     bq:u32[1,2] = slice[
#       limit_indices=(2, 2)
#       start_indices=(1, 0)
#       strides=(1, 1)
#     ] bn
#     br:u32[2] = squeeze[dimensions=(0,)] bq
#     bs:u32[1,2] = slice[
#       limit_indices=(3, 2)
#       start_indices=(2, 0)
#       strides=(1, 1)
#     ] bn
#     bt:u32[2] = squeeze[dimensions=(0,)] bs
#     bu:key<fry>[] = random_wrap[impl=fry] bp
#     bv:f32[30,10] = jit[name=_uniform jaxpr=_uniform] bu 0.0:f32[] 1.0:f32[]
#     bw:key<fry>[] = random_wrap[impl=fry] br
#     bx:f32[30,10] = jit[name=_uniform jaxpr=_uniform] bw 0.0:f32[] 1.0:f32[]
#     by:f32[] = convert_element_type[new_dtype=float32 weak_type=False] y
#     bz:f32[30,10] = mul by be
#     ca:f32[] = convert_element_type[new_dtype=float32 weak_type=False] z
#     cb:f32[30,10] = mul ca bv
#     cc:f32[30,10] = sub bf bd
#     cd:f32[30,10] = mul cb cc
#     ce:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ba
#     cf:f32[30,10] = mul ce bx
#     cg:f32[1,10] = broadcast_in_dim[
#       broadcast_dimensions=(1,)
#       shape=(1, 10)
#       sharding=None
#     ] bh
#     ch:f32[30,10] = sub cg bd
#     ci:f32[30,10] = mul cf ch
#     cj:f32[30,10] = add bz cd
#     ck:f32[30,10] = add cj ci
#     cl:f32[30,10] = add bd ck
#     cm:f32[30,10] = jit[
#       name=clip
#       jaxpr={ lambda ; cl:f32[30,10] bb:f32[] bc:f32[]. let
#           cn:f32[] = convert_element_type[new_dtype=float32 weak_type=False] bb
#           co:f32[30,10] = max cn cl
#           cp:f32[] = convert_element_type[new_dtype=float32 weak_type=False] bc
#           cm:f32[30,10] = min cp co
#         in (cm,) }
#     ] cl bb bc
#     cq:f32[30] = jit[
#       name=elliptic_jax
#       jaxpr={ lambda ; cm:f32[30,10]. let
#           cr:i32[10] = iota[dimension=0 dtype=int32 shape=(10,) sharding=None]
#           cs:f32[10] = convert_element_type[new_dtype=float32 weak_type=False] cr
#           ct:f32[10] = div cs 9.0:f32[]
#           cu:f32[10] = pow 1000000.0:f32[] ct
#           cv:f32[30,10] = integer_pow[y=2] cm
#           cw:f32[1,10] = broadcast_in_dim[
#             broadcast_dimensions=(np.int64(1),)
#             shape=(1, 10)
#             sharding=None
#           ] cu
#           cx:f32[30,10] = mul cw cv
#           cq:f32[30] = reduce_sum[axes=(np.int64(1),) out_sharding=None] cx
#         in (cq,) }
#     ] cm
#     cy:bool[30] = lt cq bg
#     cz:bool[30,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(30, 1)
#       sharding=None
#     ] cy
#     da:f32[30,10] = jit[
#       name=_where
#       jaxpr={ lambda ; cz:bool[30,1] cm:f32[30,10] bf:f32[30,10]. let
#           db:bool[30,10] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(30, 10)
#             sharding=None
#           ] cz
#           da:f32[30,10] = select_n db bf cm
#         in (da,) }
#     ] cz cm bf
#     dc:f32[30] = jit[
#       name=_where
#       jaxpr={ lambda ; cy:bool[30] cq:f32[30] bg:f32[30]. let
#           dc:f32[30] = select_n cy bg cq
#         in (dc,) }
#     ] cy cq bg
#     dd:i32[] = argmin[axes=(0,) index_dtype=int32] dc
#     de:bool[] = lt dd 0:i32[]
#     df:i32[] = add dd 30:i32[]
#     dg:i32[] = select_n de dd df
#     dh:f32[1] = dynamic_slice[slice_sizes=(1,)] dc dg
#     di:f32[] = squeeze[dimensions=(0,)] dh
#     dj:bool[] = lt di bi
#     dk:bool[] = lt dd 0:i32[]
#     dl:i32[] = add dd 30:i32[]
#     dm:i32[] = select_n dk dd dl
#     dn:f32[1,10] = dynamic_slice[slice_sizes=(1, 10)] da dm 0:i32[]
#     do:f32[10] = squeeze[dimensions=(0,)] dn
#     dp:f32[10] = jit[name=_where jaxpr=_where] dj do bh
#     dq:f32[] = jit[name=_where jaxpr=_where1] dj di bi
#     dr:i32[] = jit[
#       name=remainder
#       jaxpr={ lambda ; bk:i32[] ds:i32[]. let
#           dt:i32[] = convert_element_type[new_dtype=int32 weak_type=False] ds
#           du:bool[] = eq dt 0:i32[]
#           dv:i32[] = jit[
#             name=_where
#             jaxpr={ lambda ; du:bool[] dw:i32[] dt:i32[]. let
#                 dv:i32[] = select_n du dt dw
#               in (dv,) }
#           ] du 1:i32[] dt
#           dx:i32[] = rem bk dv
#           dy:bool[] = ne dx 0:i32[]
#           dz:bool[] = lt dx 0:i32[]
#           ea:bool[] = lt dv 0:i32[]
#           eb:bool[] = ne dz ea
#           ec:bool[] = and eb dy
#           ed:i32[] = add dx dv
#           dr:i32[] = select_n ec dx ed
#         in (dr,) }
#     ] bk 10:i32[]
#     ee:bool[] = eq dr 0:i32[]
#     ef:i32[] = convert_element_type[new_dtype=int32 weak_type=False] ee
#     eg:f32[10] eh:f32[] = cond[
#       branches=(
#         { lambda ; ei:f32[] ej:f32[] ek:f32[10] el:f32[]. let  in (ek, el) }
#         { lambda ; em:f32[] en:f32[] eo:f32[10] ep:f32[]. let
#             eq:f32[10] _:f32[10] _:f32[] = scan[
#               _split_transpose=False
#               jaxpr={ lambda ; er:f32[] es:f32[] et:f32[10] eu:f32[10] ev:f32[]. let
#                   ew:f32[10] ex:f32[10] ey:f32[] = jit[
#                     name=update
#                     jaxpr={ lambda ; et:f32[10] eu:f32[10] ev:f32[]. let
#                         ez:f32[10] fa:f32[10] = jit[
#                           name=elliptic_jax
#                           jaxpr={ lambda ; eu:f32[10]. let
#                               fb:i32[10] = iota[
#                                 dimension=0
#                                 dtype=int32
#                                 shape=(10,)
#                                 sharding=None
#                               ]
#                               fc:f32[10] = convert_element_type[
#                                 new_dtype=float32
#                                 weak_type=False
#                               ] fb
#                               fd:f32[10] = div fc 9.0:f32[]
#                               fa:f32[10] = pow 1000000.0:f32[] fd
#                               fe:f32[10] = integer_pow[y=1] eu
#                               ez:f32[10] = mul 2.0:f32[] fe
#                             in (ez, fa) }
#                         ] eu
#                         ff:f32[10] = jit[
#                           name=elliptic_jax
#                           jaxpr={ lambda ; ez:f32[10] fa:f32[10] fg:f32[]. let
#                               fh:f32[10] = broadcast_in_dim[
#                                 broadcast_dimensions=()
#                                 shape=(10,)
#                                 sharding=None
#                               ] fg
#                               fi:f32[10] = mul fa fh
#                               ff:f32[10] = mul fi ez
#                             in (ff,) }
#                         ] ez fa 1.0:f32[]
#                         fj:f32[10] = mul -0.0010000000474974513:f32[] ff
#                         ew:f32[10] = add eu fj
#                         fk:f32[] = integer_pow[y=2] ev
#                         fl:f32[] = mul 4.0:f32[] fk
#                         fm:f32[] = add 1.0:f32[] fl
#                         fn:f32[] = sqrt fm
#                         fo:f32[] = add 1.0:f32[] fn
#                         ey:f32[] = mul 0.5:f32[] fo
#                         fp:f32[10] = sub ew et
#                         fq:f32[] = sub ev 1.0:f32[]
#                         fr:f32[] = div fq ey
#                         fs:f32[] = convert_element_type[
#                           new_dtype=float32
#                           weak_type=False
#                         ] fr
#                         ft:f32[10] = mul fs fp
#                         ex:f32[10] = add ew ft
#                       in (ew, ex, ey) }
#                   ] et eu ev
#                   fu:f32[10] = jit[
#                     name=clip
#                     jaxpr={ lambda ; ew:f32[10] er:f32[] es:f32[]. let
#                         fv:f32[] = convert_element_type[
#                           new_dtype=float32
#                           weak_type=False
#                         ] er
#                         fw:f32[10] = max fv ew
#                         fx:f32[] = convert_element_type[
#                           new_dtype=float32
#                           weak_type=False
#                         ] es
#                         fu:f32[10] = min fx fw
#                       in (fu,) }
#                   ] ew er es
#                 in (fu, ex, ey) }
#               length=10
#               linear=(False, False, False, False, False)
#               num_carry=3
#               num_consts=2
#               reverse=False
#               unroll=1
#             ] em en eo eo 1.0:f32[]
#             fy:f32[] = jit[
#               name=elliptic_jax
#               jaxpr={ lambda ; eq:f32[10]. let
#                   fz:i32[10] = iota[
#                     dimension=0
#                     dtype=int32
#                     shape=(10,)
#                     sharding=None
#                   ]
#                   ga:f32[10] = convert_element_type[
#                     new_dtype=float32
#                     weak_type=False
#                   ] fz
#                   gb:f32[10] = div ga 9.0:f32[]
#                   gc:f32[10] = pow 1000000.0:f32[] gb
#                   gd:f32[10] = integer_pow[y=2] eq
#                   ge:f32[10] = mul gc gd
#                   fy:f32[] = reduce_sum[axes=(0,) out_sharding=None] ge
#                 in (fy,) }
#             ] eq
#           in (eq, fy) }
#       )
#     ] ef bb bc dp dq
#     gf:bool[] = lt eh dq
#     gg:f32[10] = jit[name=_where jaxpr=_where] gf eg dp
#     gh:f32[] = jit[name=_where jaxpr=_where1] gf eh dq
#     gi:bool[] = lt gh bi
#     gj:i32[30] = iota[dimension=0 dtype=int32 shape=(30,) sharding=None]
#     gk:bool[30] = eq gj dd
#     gl:bool[30,1] = broadcast_in_dim[
#       broadcast_dimensions=(0,)
#       shape=(30, 1)
#       sharding=None
#     ] gk
#     gm:bool[] = and gf gi
#     gn:bool[30,1] = and gm gl
#     go:f32[30,10] = jit[
#       name=_where
#       jaxpr={ lambda ; gn:bool[30,1] gg:f32[10] da:f32[30,10]. let
#           gp:bool[30,10] = broadcast_in_dim[
#             broadcast_dimensions=(0, 1)
#             shape=(30, 10)
#             sharding=None
#           ] gn
#           gq:f32[30,10] = broadcast_in_dim[
#             broadcast_dimensions=(1,)
#             shape=(30, 10)
#             sharding=None
#           ] gg
#           go:f32[30,10] = select_n gp da gq
#         in (go,) }
#     ] gn gg da
#     gr:bool[] = and gf gi
#     gs:i32[30] = iota[dimension=0 dtype=int32 shape=(30,) sharding=None]
#     gt:bool[30] = eq gs dd
#     gu:bool[30] = and gr gt
#     gv:f32[30] = jit[
#       name=_where
#       jaxpr={ lambda ; gu:bool[30] gh:f32[] dc:f32[30]. let
#           gw:f32[30] = broadcast_in_dim[
#             broadcast_dimensions=()
#             shape=(30,)
#             sharding=None
#           ] gh
#           gv:f32[30] = select_n gu dc gw
#         in (gv,) }
#     ] gu gh dc
#   in (cm, ck, go, gv, gg, gh, bt, gh) }, ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2495, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, num_const_args, effects, in_avals, arg_names, result_names)
#    2494 try:
# -> 2495   func_op, _, _ = ctx.cached_primitive_lowerings[key]
#    2496 except KeyError:
#
# KeyError: ('closed_call', { lambda ; a:f32[] b:f32[] c:f32[10] d:f32[10] e:f32[]. let
#     f:f32[10] g:f32[10] h:f32[] = jit[
#       name=update
#       jaxpr={ lambda ; c:f32[10] d:f32[10] e:f32[]. let
#           i:f32[10] j:f32[10] = jit[
#             name=elliptic_jax
#             jaxpr={ lambda ; d:f32[10]. let
#                 k:i32[10] = iota[
#                   dimension=0
#                   dtype=int32
#                   shape=(10,)
#                   sharding=None
#                 ]
#                 l:f32[10] = convert_element_type[
#                   new_dtype=float32
#                   weak_type=False
#                 ] k
#                 m:f32[10] = div l 9.0:f32[]
#                 j:f32[10] = pow 1000000.0:f32[] m
#                 n:f32[10] = integer_pow[y=1] d
#                 i:f32[10] = mul 2.0:f32[] n
#               in (i, j) }
#           ] d
#           o:f32[10] = jit[
#             name=elliptic_jax
#             jaxpr={ lambda ; i:f32[10] j:f32[10] p:f32[]. let
#                 q:f32[10] = broadcast_in_dim[
#                   broadcast_dimensions=()
#                   shape=(10,)
#                   sharding=None
#                 ] p
#                 r:f32[10] = mul j q
#                 o:f32[10] = mul r i
#               in (o,) }
#           ] i j 1.0:f32[]
#           s:f32[10] = mul -0.0010000000474974513:f32[] o
#           f:f32[10] = add d s
#           t:f32[] = integer_pow[y=2] e
#           u:f32[] = mul 4.0:f32[] t
#           v:f32[] = add 1.0:f32[] u
#           w:f32[] = sqrt v
#           x:f32[] = add 1.0:f32[] w
#           h:f32[] = mul 0.5:f32[] x
#           y:f32[10] = sub f c
#           z:f32[] = sub e 1.0:f32[]
#           ba:f32[] = div z h
#           bb:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ba
#           bc:f32[10] = mul bb y
#           g:f32[10] = add f bc
#         in (f, g, h) }
#     ] c d e
#     bd:f32[10] = jit[
#       name=clip
#       jaxpr={ lambda ; f:f32[10] a:f32[] b:f32[]. let
#           be:f32[] = convert_element_type[new_dtype=float32 weak_type=False] a
#           bf:f32[10] = max be f
#           bg:f32[] = convert_element_type[new_dtype=float32 weak_type=False] b
#           bd:f32[10] = min bg bf
#         in (bd,) }
#     ] f a b
#   in (bd, g, h) }, ())
#
# During handling of the above exception, another exception occurred:
#
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py:758, in start()
#     757 try:
# --> 758     self.io_loop.start()
#     759 except KeyboardInterrupt:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/asyncio/base_events.py:645, in run_forever()
#     644 while True:
# --> 645     self._run_once()
#     646     if self._stopping:
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/asyncio/base_events.py:1999, in _run_once()
#    1998     else:
# -> 1999         handle._run()
#    2000 handle = None
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/asyncio/events.py:88, in _run()
#      87 try:
# ---> 88     self._context.run(self._callback, *self._args)
#      89 except (SystemExit, KeyboardInterrupt):
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:621, in shell_main()
#     620 async with asyncio_lock:
# --> 621     await self.dispatch_shell(msg, subshell_id=subshell_id)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:478, in dispatch_shell()
#     477     if inspect.isawaitable(result):
# --> 478         await result
#     479 except Exception:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py:372, in execute_request()
#     371 """Override for cell output - cell reconciliation."""
# --> 372 await super().execute_request(stream, ident, parent)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:834, in execute_request()
#     833 if inspect.isawaitable(reply_content):
# --> 834     reply_content = await reply_content
#     835 else:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py:464, in do_execute()
#     463 if accepts_params["cell_id"]:
# --> 464     res = shell.run_cell(
#     465         code,
#     466         store_history=store_history,
#     467         silent=silent,
#     468         cell_id=cell_id,
#     469     )
#     470 else:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py:663, in run_cell()
#     662 self._last_traceback = None
# --> 663 return super().run_cell(*args, **kwargs)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3169, in run_cell()
#    3168 try:
# -> 3169     result = self._run_cell(
#    3170         raw_cell, store_history, silent, shell_futures, cell_id
#    3171     )
#    3172 finally:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3224, in _run_cell()
#    3223 try:
# -> 3224     result = runner(coro)
#    3225 except BaseException as e:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3446, in run_cell_async()
#    3443 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3446 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3447        interactivity=interactivity, compiler=compiler, result=result)
#    3449 self.last_execution_succeeded = not has_raised
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3687, in run_ast_nodes()
#    3686     asy = compare(code)
# -> 3687 if await self.run_code(code, result, async_=asy):
#    3688     return True
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3747, in run_code()
#    3746     else:
# -> 3747         exec(code_obj, self.user_global_ns, self.user_ns)
#    3748 finally:
#    3749     # Reset our crash handler in place
#
# Cell In[108], line 1
# ----> 1 results = run_experiment()
#       2 df = pd.DataFrame(results)
#
# Cell In[107], line 32, in run_experiment()
#      31     hyperparameters["seed"] = random.PRNGKey(i)
# ---> 32     algorithm_fn(objective_fn, bounds, **hyperparameters)
#      34 start = time.perf_counter()
#
# Cell In[99], line 32, in pso_jax()
#      31 init_velocities = random.uniform(k_vel, (num_particles, num_dims), minval=-limit, maxval=limit)
# ---> 32 init_fitness = vmap(objective_fn)(init_positions)
#      34 best_idx = jnp.argmin(init_fitness)
#
# Cell In[104], line 25, in elliptic_jax()
#      24 coeffs = (1e6) ** (i / (n - 1))
# ---> 25 return jnp.sum(coeffs * x**2)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1146, in op()
#    1145 def op(self, *args):
# -> 1146   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:609, in deferring_binary_op()
#     608 if isinstance(other, _accepted_binop_types):
# --> 609   return binary_op(*args)
#     610 # Note: don't use isinstance here, because we don't want to raise for
#     611 # subclasses, e.g. NamedTuple objects that may override operators.
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:182, in __call__()
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 results = run_experiment()
#       2 df = pd.DataFrame(results)
#
# Cell In[107], line 32, in run_experiment()
#      30 if "JAX" in algorithm_name:
#      31     hyperparameters["seed"] = random.PRNGKey(i)
# ---> 32     algorithm_fn(objective_fn, bounds, **hyperparameters)
#      34 start = time.perf_counter()
#      35 result = algorithm_fn(objective_fn, bounds, **hyperparameters)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:259, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     256                      "`jit`, but 'no_tracing' is set")
#     257 p, args_flat = _trace_for_jit(fun, jit_info, args, kwargs)
#     258 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 259  executable, pgle_profiler, const_args) = _run_python_pjit(
#     260      p, args_flat, fun, jit_info, args, kwargs)
#     262 maybe_fastpath_data = _get_fastpath_data(
#     263     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     264     pgle_profiler, const_args)
#     266 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:142, in _run_python_pjit(p, args_flat, fun, jit_info, args, kwargs)
#     140   args_flat = map(core.full_lower, args_flat)
#     141   core.check_eval_args(args_flat)
# --> 142   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     143       *args_flat, **p.params)
#     144 else:
#     145   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1192, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1189 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1190 # initialize the fdo_profile compile option.
#    1191 arg_types = map(convert_to_metaty, args)
# -> 1192 computation = _resolve_and_lower(
#    1193     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1194     out_shardings=out_shardings, in_layouts=in_layouts,
#    1195     out_layouts=out_layouts, donated_invars=donated_invars,
#    1196     ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1197     inline=inline, lowering_platforms=None,
#    1198     lowering_parameters=mlir.LoweringParameters(),
#    1199     pgle_profiler=pgle_profiler,
#    1200     compiler_options_kvs=compiler_options_kvs,
#    1201 )
#    1202 compiled = computation.compile()
#    1204 # This check is expensive so only do it if enable_checks is on.
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1118, in _resolve_and_lower(args, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, lowering_platforms, lowering_parameters, pgle_profiler, compiler_options_kvs)
#    1115 in_layouts = _resolve_in_layouts(args, in_layouts, in_shardings,
#    1116                                  jaxpr.in_avals)
#    1117 out_layouts = _resolve_out_layouts(out_layouts, out_shardings, jaxpr.out_avals)
# -> 1118 return _pjit_lower(
#    1119     jaxpr, in_shardings, out_shardings, in_layouts, out_layouts,
#    1120     donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs,
#    1121     lowering_platforms=lowering_platforms,
#    1122     lowering_parameters=lowering_parameters,
#    1123     pgle_profiler=pgle_profiler)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1298, in _pjit_lower(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    1281 @weakref_lru_cache
#    1282 def _pjit_lower(
#    1283     jaxpr: core.ClosedJaxpr,
#    (...)   1296     lowering_parameters: mlir.LoweringParameters,
#    1297     pgle_profiler: profiler.PGLEProfiler | None) -> pxla.MeshComputation:
# -> 1298   return pxla.lower_sharding_computation(
#    1299       jaxpr, 'jit', name, in_shardings, out_shardings,
#    1300       in_layouts, out_layouts, tuple(donated_invars),
#    1301       keep_unused=keep_unused, context_mesh=ctx_mesh,
#    1302       compiler_options_kvs=compiler_options_kvs,
#    1303       lowering_platforms=lowering_platforms,
#    1304       lowering_parameters=lowering_parameters,
#    1305       pgle_profiler=pgle_profiler)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:359, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     356 @wraps(func)
#     357 def wrapper(*args, **kwargs):
#     358   with TraceAnnotation(name, **decorator_kwargs):
# --> 359     return func(*args, **kwargs)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2394, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, keep_unused, context_mesh, compiler_options_kvs, lowering_platforms, lowering_parameters, pgle_profiler)
#    2390 jaxpr_util.maybe_dump_jaxpr_to_file(fun_name, closed_jaxpr.jaxpr)
#    2391 module_name = util.wrap_name(api_name, fun_name)
#    2393 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2394  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2395      closed_jaxpr, module_name, backend,
#    2396      len(const_args), tuple(global_in_avals),
#    2397      semantic_in_shardings, semantic_out_shardings,
#    2398      in_layouts, out_layouts, num_devices,
#    2399      tuple(device_list) if prim_requires_devices else None,  # type: ignore[arg-type]
#    2400      donated_invars, all_default_mem_kind, inout_aliases,
#    2401      propagated_out_mem_kinds, platforms,
#    2402      lowering_parameters=lowering_parameters,
#    2403      abstract_mesh=abstract_mesh)
#    2405 # backend and device_assignment is passed through to MeshExecutable because
#    2406 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2407 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2408 # because we calculate the device_assignment and backend before in_shardings,
#    2409 # etc are pruned.
#    2410 return MeshComputation(
#    2411     module_name,
#    2412     module,
#    (...)   2440     intermediate_shardings=unique_intermediate_shardings,
#    2441     context_mesh=context_mesh)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1990, in _cached_lowering_to_hlo(closed_jaxpr, module_name, backend, num_const_args, in_avals, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, all_default_mem_kind, inout_aliases, propagated_out_mem_kinds, platforms, lowering_parameters, abstract_mesh)
#    1986 arg_names = ("",) * num_const_args + jaxpr._debug_info.safe_arg_names(len(in_avals) - num_const_args)
#    1987 with dispatch.log_elapsed_time(
#    1988       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time:.9f} sec",
#    1989       fun_name=module_name, event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1990   lowering_result = mlir.lower_jaxpr_to_module(
#    1991       module_name,
#    1992       closed_jaxpr,
#    1993       num_const_args=num_const_args,
#    1994       ordered_effects=ordered_effects,
#    1995       backend=backend,
#    1996       platforms=platforms,
#    1997       axis_context=axis_ctx,
#    1998       in_avals=in_avals,
#    1999       donated_args=donated_invars,
#    2000       replicated_args=replicated_args,
#    2001       arg_shardings=in_mlir_shardings,
#    2002       result_shardings=out_mlir_shardings,
#    2003       in_layouts=in_layouts,
#    2004       out_layouts=out_layouts,
#    2005       arg_names=arg_names,
#    2006       result_names=jaxpr._debug_info.safe_result_paths(len(out_avals)),
#    2007       num_replicas=nreps,
#    2008       num_partitions=num_partitions,
#    2009       all_default_mem_kind=all_default_mem_kind,
#    2010       input_output_aliases=inout_aliases,
#    2011       propagated_out_mem_kinds=propagated_out_mem_kinds,
#    2012       lowering_parameters=lowering_parameters)
#    2013 tuple_args = dispatch.should_tuple_args(len(in_avals), backend.platform)
#    2014 unordered_effects = list(
#    2015     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1312, in lower_jaxpr_to_module(***failed resolving arguments***)
#    1310   attrs["mhlo.num_replicas"] = i32_attr(num_replicas)
#    1311   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
# -> 1312   lower_jaxpr_to_fun(
#    1313       ctx, module_name, jaxpr, ordered_effects,
#    1314       num_const_args=num_const_args,
#    1315       main_function=True,
#    1316       replicated_args=replicated_args,
#    1317       in_avals=in_avals,
#    1318       arg_shardings=arg_shardings,
#    1319       result_shardings=result_shardings,
#    1320       input_output_aliases=input_output_aliases,
#    1321       xla_donated_args=xla_donated_args,
#    1322       arg_names=arg_names,
#    1323       result_names=result_names,
#    1324       arg_memory_kinds=arg_memory_kinds,
#    1325       result_memory_kinds=result_memory_kinds,
#    1326       arg_layouts=in_layouts,
#    1327       result_layouts=out_layouts,
#    1328       propagated_out_mem_kinds=propagated_out_mem_kinds)
#    1330 try:
#    1331   if not ctx.module.operation.verify():
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1889, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, num_const_args, main_function, replicated_args, in_avals, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1883 unique_consts = {
#    1884     id(c): ir_constant(c, aval=var.aval)
#    1885     for c, var in zip(jaxpr.consts, jaxpr.jaxpr.constvars)
#    1886 }
#    1887 consts_for_constvars = [unique_consts[id(c)] for c in jaxpr.consts]
# -> 1889 out_vals, tokens_out = jaxpr_subcomp(
#    1890     ctx, jaxpr.jaxpr, name_stack, tokens_in,
#    1891     consts_for_constvars, *args, dim_var_values=dim_var_values,
#    1892     const_lowering=const_lowering)
#    1893 outs: list[IrValues] = []
#    1894 for eff in effects:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2067, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2064   loc = source_info_to_location(ctx, None, eqn_name_stack,
#    2065                                 eqn.source_info.traceback)
#    2066   with loc:
# -> 2067     out_nodes, tokens_out = _cached_lowering(
#    2068         ctx, eqn, tokens_in, tuple(dim_var_values), const_lowering,
#    2069         *in_nodes, **eqn.params)
#    2070 else:
#    2071   # If we cannot cache the lowering, lower inline.
#    2072   axis_size_env = None
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2126, in _cached_lowering(ctx, eqn, tokens_in, dim_var_values, const_lowering, *args, **params)
#    2124 if cache_entry is None:
#    2125   avals_out = map(lambda v: v.aval, eqn.outvars)
# -> 2126   cache_entry = _emit_lowering_rule_as_fun(
#    2127       partial(_uncached_lowering, eqn.primitive, eqn.ctx, eqn.effects), ctx,
#    2128       eqn.ctx, eqn.primitive, ordered_effects, avals_in,
#    2129       avals_out, **params)
#    2130   ctx.lowering_cache[cache_key] = cache_entry
#    2132 tokens_in_args = tuple(tokens_in.get(eff) for eff in ordered_effects)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2205, in _emit_lowering_rule_as_fun(lowering_rule, ctx, eqn_ctx, primitive, ordered_effects, avals_in, avals_out, **params)
#    2196 sub_ctx = LoweringRuleContext(
#    2197     module_context=ctx, primitive=primitive,
#    2198     name_stack=source_info_util.new_name_stack(),
#    (...)   2202     tokens_out=None, jaxpr_eqn_ctx=eqn_ctx, dim_var_values=dim_var_values,
#    2203     const_lowering=const_lowering)
#    2204 with ir.Location.name(str(primitive.name)):
# -> 2205   outs, inline = lowering_rule(sub_ctx, *unflattened_args, **params)
#    2206 if sub_ctx.tokens_out:
#    2207   outs = [*[sub_ctx.tokens_out.get(eff) for eff in ordered_effects], *outs]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2374, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2372 # If there is a single rule left just apply the rule, without conditionals.
#    2373 if len(kept_rules) == 1:
# -> 2374   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2375   foreach(
#    2376       lambda o: wrap_compute_type_in_place(ctx, _get_owner(o)),
#    2377       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2378   )
#    2379   foreach(
#    2380       lambda o: wrap_xla_metadata_in_place(ctx, _get_owner(o)),
#    2381       flatten_ir_values(output),
#    2382   )
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2475, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    2473 else:
#    2474   sub_context = ctx.module_context
# -> 2475 out, tokens = jaxpr_subcomp(
#    2476     sub_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    2477     ir_consts(consts_for_constvars, [v.aval for v in jaxpr.constvars]),
#    2478     *args,
#    2479     dim_var_values=ctx.dim_var_values,
#    2480     const_lowering=ctx.const_lowering)
#    2481 ctx.set_tokens_out(tokens)
#    2482 return out
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2067, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2064   loc = source_info_to_location(ctx, None, eqn_name_stack,
#    2065                                 eqn.source_info.traceback)
#    2066   with loc:
# -> 2067     out_nodes, tokens_out = _cached_lowering(
#    2068         ctx, eqn, tokens_in, tuple(dim_var_values), const_lowering,
#    2069         *in_nodes, **eqn.params)
#    2070 else:
#    2071   # If we cannot cache the lowering, lower inline.
#    2072   axis_size_env = None
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2126, in _cached_lowering(ctx, eqn, tokens_in, dim_var_values, const_lowering, *args, **params)
#    2124 if cache_entry is None:
#    2125   avals_out = map(lambda v: v.aval, eqn.outvars)
# -> 2126   cache_entry = _emit_lowering_rule_as_fun(
#    2127       partial(_uncached_lowering, eqn.primitive, eqn.ctx, eqn.effects), ctx,
#    2128       eqn.ctx, eqn.primitive, ordered_effects, avals_in,
#    2129       avals_out, **params)
#    2130   ctx.lowering_cache[cache_key] = cache_entry
#    2132 tokens_in_args = tuple(tokens_in.get(eff) for eff in ordered_effects)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2205, in _emit_lowering_rule_as_fun(lowering_rule, ctx, eqn_ctx, primitive, ordered_effects, avals_in, avals_out, **params)
#    2196 sub_ctx = LoweringRuleContext(
#    2197     module_context=ctx, primitive=primitive,
#    2198     name_stack=source_info_util.new_name_stack(),
#    (...)   2202     tokens_out=None, jaxpr_eqn_ctx=eqn_ctx, dim_var_values=dim_var_values,
#    2203     const_lowering=const_lowering)
#    2204 with ir.Location.name(str(primitive.name)):
# -> 2205   outs, inline = lowering_rule(sub_ctx, *unflattened_args, **params)
#    2206 if sub_ctx.tokens_out:
#    2207   outs = [*[sub_ctx.tokens_out.get(eff) for eff in ordered_effects], *outs]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2374, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2372 # If there is a single rule left just apply the rule, without conditionals.
#    2373 if len(kept_rules) == 1:
# -> 2374   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2375   foreach(
#    2376       lambda o: wrap_compute_type_in_place(ctx, _get_owner(o)),
#    2377       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2378   )
#    2379   foreach(
#    2380       lambda o: wrap_xla_metadata_in_place(ctx, _get_owner(o)),
#    2381       flatten_ir_values(output),
#    2382   )
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/lax/control_flow/loops.py:2018, in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    2013 body_name_stack = name_stack.extend('body')
#    2014 body_consts = [
#    2015     mlir.ir_constant(x, aval=var.aval)
#    2016     for x, var in zip(body_jaxpr.consts, body_jaxpr.jaxpr.constvars)
#    2017 ]
# -> 2018 new_z, tokens_out = mlir.jaxpr_subcomp(
#    2019     ctx.module_context, body_jaxpr.jaxpr, body_name_stack,
#    2020     tokens_in, body_consts, *(y + z),
#    2021     dim_var_values=ctx.dim_var_values, const_lowering=ctx.const_lowering)
#    2022 out_tokens = [tokens_out.get(eff) for eff in body_effects]
#    2023 if batched:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2083, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2072   axis_size_env = None
#    2073   rule_ctx = LoweringRuleContext(
#    2074       module_context=ctx, primitive=eqn.primitive,
#    2075       name_stack=eqn_name_stack,
#    (...)   2081       axis_size_env=axis_size_env,
#    2082       const_lowering=const_lowering)
# -> 2083   out_nodes, _inline = _uncached_lowering(
#    2084       eqn.primitive, eqn.ctx, eqn.effects, rule_ctx, *in_nodes,
#    2085       **eqn.params)
#    2086   tokens_out = rule_ctx.tokens_out
#    2088 assert len(out_nodes) == len(eqn.outvars), (out_nodes, eqn)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# ...
# -> 2545 func_op = _lower_jaxpr_to_fun_cached(
#    2546     ctx, fn_name, call_jaxpr, num_const_args, effects, in_avals=in_avals,
#    2547     arg_names=arg_names, result_names=result_names)
#    2548 return func_op, output_types, effects
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2498, in _lower_jaxpr_to_fun_cached(ctx, fn_name, call_jaxpr, num_const_args, effects, in_avals, arg_names, result_names)
#    2496 except KeyError:
#    2497   num_callbacks = len(ctx.host_callbacks)
# -> 2498   func_op = lower_jaxpr_to_fun(
#    2499       ctx, fn_name, call_jaxpr, effects, num_const_args=num_const_args,
#    2500       in_avals=in_avals, arg_names=arg_names, result_names=result_names)
#    2501   # If this Jaxpr includes callbacks, we can't cache the lowering because
#    2502   # on TPU under libtpu <= 0.0.34 every callback must have a globally
#    2503   # unique channel, but the channel gets assigned during lowering.
#    2504   has_callbacks = len(ctx.host_callbacks) > num_callbacks
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1889, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, num_const_args, main_function, replicated_args, in_avals, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1883 unique_consts = {
#    1884     id(c): ir_constant(c, aval=var.aval)
#    1885     for c, var in zip(jaxpr.consts, jaxpr.jaxpr.constvars)
#    1886 }
#    1887 consts_for_constvars = [unique_consts[id(c)] for c in jaxpr.consts]
# -> 1889 out_vals, tokens_out = jaxpr_subcomp(
#    1890     ctx, jaxpr.jaxpr, name_stack, tokens_in,
#    1891     consts_for_constvars, *args, dim_var_values=dim_var_values,
#    1892     const_lowering=const_lowering)
#    1893 outs: list[IrValues] = []
#    1894 for eff in effects:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2083, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2072   axis_size_env = None
#    2073   rule_ctx = LoweringRuleContext(
#    2074       module_context=ctx, primitive=eqn.primitive,
#    2075       name_stack=eqn_name_stack,
#    (...)   2081       axis_size_env=axis_size_env,
#    2082       const_lowering=const_lowering)
# -> 2083   out_nodes, _inline = _uncached_lowering(
#    2084       eqn.primitive, eqn.ctx, eqn.effects, rule_ctx, *in_nodes,
#    2085       **eqn.params)
#    2086   tokens_out = rule_ctx.tokens_out
#    2088 assert len(out_nodes) == len(eqn.outvars), (out_nodes, eqn)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2374, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2372 # If there is a single rule left just apply the rule, without conditionals.
#    2373 if len(kept_rules) == 1:
# -> 2374   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2375   foreach(
#    2376       lambda o: wrap_compute_type_in_place(ctx, _get_owner(o)),
#    2377       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2378   )
#    2379   foreach(
#    2380       lambda o: wrap_xla_metadata_in_place(ctx, _get_owner(o)),
#    2381       flatten_ir_values(output),
#    2382   )
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1426, in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, keep_unused, inline, compiler_options_kvs, *args)
#    1423 ca_layouts = const_args_layouts(const_args, const_arg_avals, ca_shardings)
#    1424 in_layouts = ca_layouts + in_layouts  # type: ignore
# -> 1426 func = _pjit_cached_lower_jaxpr_to_fun(
#    1427     ctx, name, jaxpr, len(const_args), in_avals,
#    1428     tuple(effects), in_shardings,
#    1429     out_shardings, in_layouts, out_layouts,
#    1430     api_name='jit')
#    1432 tokens_in = [ctx.tokens_in.get(eff) for eff in effects]
#    1433 hoisted_const_values = [
#    1434     mlir.ir_constant(c, const_lowering=ctx.const_lowering, aval=aval)
#    1435     for c, aval in const_args_and_avals
#    1436 ]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1393, in _pjit_cached_lower_jaxpr_to_fun(ctx, name, jaxpr, num_const_args, in_avals, effects, in_shardings, out_shardings, in_layouts, out_layouts, api_name)
#    1388 # TODO(b/228598865): non-top-level functions cannot have shardings set
#    1389 # directly on the inputs or outputs because they are lost during MLIR->HLO
#    1390 # conversion. using_sharding_annotation=False means we add an identity
#    1391 # operation instead.
#    1392 num_callbacks = len(mod_ctx.host_callbacks)
# -> 1393 func = mlir.lower_jaxpr_to_fun(
#    1394     mod_ctx, name, jaxpr, effects,
#    1395     num_const_args=num_const_args, in_avals=in_avals,
#    1396     arg_shardings=arg_shardings, result_shardings=result_shardings,
#    1397     use_sharding_annotations=False,
#    1398     arg_layouts=in_layouts, result_layouts=out_layouts)
#    1400 # If this Jaxpr includes callbacks, we can't cache the lowering because
#    1401 # on TPU every callback must have a globally unique channel under
#    1402 # libtpu <= 0.0.34, but the channel gets assigned during lowering.
#    1403 has_callbacks = len(mod_ctx.host_callbacks) > num_callbacks
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1889, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, num_const_args, main_function, replicated_args, in_avals, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1883 unique_consts = {
#    1884     id(c): ir_constant(c, aval=var.aval)
#    1885     for c, var in zip(jaxpr.consts, jaxpr.jaxpr.constvars)
#    1886 }
#    1887 consts_for_constvars = [unique_consts[id(c)] for c in jaxpr.consts]
# -> 1889 out_vals, tokens_out = jaxpr_subcomp(
#    1890     ctx, jaxpr.jaxpr, name_stack, tokens_in,
#    1891     consts_for_constvars, *args, dim_var_values=dim_var_values,
#    1892     const_lowering=const_lowering)
#    1893 outs: list[IrValues] = []
#    1894 for eff in effects:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2083, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2072   axis_size_env = None
#    2073   rule_ctx = LoweringRuleContext(
#    2074       module_context=ctx, primitive=eqn.primitive,
#    2075       name_stack=eqn_name_stack,
#    (...)   2081       axis_size_env=axis_size_env,
#    2082       const_lowering=const_lowering)
# -> 2083   out_nodes, _inline = _uncached_lowering(
#    2084       eqn.primitive, eqn.ctx, eqn.effects, rule_ctx, *in_nodes,
#    2085       **eqn.params)
#    2086   tokens_out = rule_ctx.tokens_out
#    2088 assert len(out_nodes) == len(eqn.outvars), (out_nodes, eqn)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2374, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2372 # If there is a single rule left just apply the rule, without conditionals.
#    2373 if len(kept_rules) == 1:
# -> 2374   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2375   foreach(
#    2376       lambda o: wrap_compute_type_in_place(ctx, _get_owner(o)),
#    2377       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2378   )
#    2379   foreach(
#    2380       lambda o: wrap_xla_metadata_in_place(ctx, _get_owner(o)),
#    2381       flatten_ir_values(output),
#    2382   )
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1426, in _pjit_lowering(ctx, name, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, keep_unused, inline, compiler_options_kvs, *args)
#    1423 ca_layouts = const_args_layouts(const_args, const_arg_avals, ca_shardings)
#    1424 in_layouts = ca_layouts + in_layouts  # type: ignore
# -> 1426 func = _pjit_cached_lower_jaxpr_to_fun(
#    1427     ctx, name, jaxpr, len(const_args), in_avals,
#    1428     tuple(effects), in_shardings,
#    1429     out_shardings, in_layouts, out_layouts,
#    1430     api_name='jit')
#    1432 tokens_in = [ctx.tokens_in.get(eff) for eff in effects]
#    1433 hoisted_const_values = [
#    1434     mlir.ir_constant(c, const_lowering=ctx.const_lowering, aval=aval)
#    1435     for c, aval in const_args_and_avals
#    1436 ]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1393, in _pjit_cached_lower_jaxpr_to_fun(ctx, name, jaxpr, num_const_args, in_avals, effects, in_shardings, out_shardings, in_layouts, out_layouts, api_name)
#    1388 # TODO(b/228598865): non-top-level functions cannot have shardings set
#    1389 # directly on the inputs or outputs because they are lost during MLIR->HLO
#    1390 # conversion. using_sharding_annotation=False means we add an identity
#    1391 # operation instead.
#    1392 num_callbacks = len(mod_ctx.host_callbacks)
# -> 1393 func = mlir.lower_jaxpr_to_fun(
#    1394     mod_ctx, name, jaxpr, effects,
#    1395     num_const_args=num_const_args, in_avals=in_avals,
#    1396     arg_shardings=arg_shardings, result_shardings=result_shardings,
#    1397     use_sharding_annotations=False,
#    1398     arg_layouts=in_layouts, result_layouts=out_layouts)
#    1400 # If this Jaxpr includes callbacks, we can't cache the lowering because
#    1401 # on TPU every callback must have a globally unique channel under
#    1402 # libtpu <= 0.0.34, but the channel gets assigned during lowering.
#    1403 has_callbacks = len(mod_ctx.host_callbacks) > num_callbacks
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:1889, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, num_const_args, main_function, replicated_args, in_avals, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts, propagated_out_mem_kinds)
#    1883 unique_consts = {
#    1884     id(c): ir_constant(c, aval=var.aval)
#    1885     for c, var in zip(jaxpr.consts, jaxpr.jaxpr.constvars)
#    1886 }
#    1887 consts_for_constvars = [unique_consts[id(c)] for c in jaxpr.consts]
# -> 1889 out_vals, tokens_out = jaxpr_subcomp(
#    1890     ctx, jaxpr.jaxpr, name_stack, tokens_in,
#    1891     consts_for_constvars, *args, dim_var_values=dim_var_values,
#    1892     const_lowering=const_lowering)
#    1893 outs: list[IrValues] = []
#    1894 for eff in effects:
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2067, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts_for_constvars, dim_var_values, const_lowering, *args)
#    2064   loc = source_info_to_location(ctx, None, eqn_name_stack,
#    2065                                 eqn.source_info.traceback)
#    2066   with loc:
# -> 2067     out_nodes, tokens_out = _cached_lowering(
#    2068         ctx, eqn, tokens_in, tuple(dim_var_values), const_lowering,
#    2069         *in_nodes, **eqn.params)
#    2070 else:
#    2071   # If we cannot cache the lowering, lower inline.
#    2072   axis_size_env = None
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2126, in _cached_lowering(ctx, eqn, tokens_in, dim_var_values, const_lowering, *args, **params)
#    2124 if cache_entry is None:
#    2125   avals_out = map(lambda v: v.aval, eqn.outvars)
# -> 2126   cache_entry = _emit_lowering_rule_as_fun(
#    2127       partial(_uncached_lowering, eqn.primitive, eqn.ctx, eqn.effects), ctx,
#    2128       eqn.ctx, eqn.primitive, ordered_effects, avals_in,
#    2129       avals_out, **params)
#    2130   ctx.lowering_cache[cache_key] = cache_entry
#    2132 tokens_in_args = tuple(tokens_in.get(eff) for eff in ordered_effects)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2205, in _emit_lowering_rule_as_fun(lowering_rule, ctx, eqn_ctx, primitive, ordered_effects, avals_in, avals_out, **params)
#    2196 sub_ctx = LoweringRuleContext(
#    2197     module_context=ctx, primitive=primitive,
#    2198     name_stack=source_info_util.new_name_stack(),
#    (...)   2202     tokens_out=None, jaxpr_eqn_ctx=eqn_ctx, dim_var_values=dim_var_values,
#    2203     const_lowering=const_lowering)
#    2204 with ir.Location.name(str(primitive.name)):
# -> 2205   outs, inline = lowering_rule(sub_ctx, *unflattened_args, **params)
#    2206 if sub_ctx.tokens_out:
#    2207   outs = [*[sub_ctx.tokens_out.get(eff) for eff in ordered_effects], *outs]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2256, in _uncached_lowering(primitive, eqn_ctx, effects, ctx, *args, **params)
#    2254 assert not isinstance(default_rule, LoweringRuleEntry)
#    2255 assert not any(isinstance(r, LoweringRuleEntry) for r in platform_rules.values())
# -> 2256 ans = lower_per_platform(ctx, str(primitive), platform_rules, default_rule,
#    2257                          effects, *args, **params)
#    2258 try:
#    2259   rets = tuple(ans)
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2374, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    2372 # If there is a single rule left just apply the rule, without conditionals.
#    2373 if len(kept_rules) == 1:
# -> 2374   output = kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    2375   foreach(
#    2376       lambda o: wrap_compute_type_in_place(ctx, _get_owner(o)),
#    2377       filter(_is_not_block_argument, flatten_ir_values(output)),
#    2378   )
#    2379   foreach(
#    2380       lambda o: wrap_xla_metadata_in_place(ctx, _get_owner(o)),
#    2381       flatten_ir_values(output),
#    2382   )
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:4145, in _nary_lower_hlo(***failed resolving arguments***)
#    4143 if accuracy:
#    4144   out = op(*args, result_accuracy=accuracy_attr(accuracy))
# -> 4145 return [mlir.lower_with_sharding_in_types(ctx, out, aval_out)]
#
# File ~/Desktop/repositories/pso/.venv/lib/python3.12/site-packages/jax/_src/interpreters/mlir.py:2923, in lower_with_sharding_in_types(ctx, op, aval, sharding_proto)
#    2919 wrap_with_full_to_shard_op = partial(_wrap_with_spmd_op, "SPMDFullToShardShape")
#    2920 wrap_with_shard_to_full_op = partial(_wrap_with_spmd_op, "SPMDShardToFullShape")
# -> 2923 def lower_with_sharding_in_types(ctx, op, aval, sharding_proto=None):
#    2924   if aval.sharding.mesh.empty:
#    2925     return op
#
# KeyboardInterrupt:

# %%
df.to_csv(config["output_path"] / "experiment_results.csv")

# %%
generate_visualizations(df, config)
